# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl

# %%
data=[24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]

# %%
np.mean(data)
# Out:
# 33.27133333333333

# %%
np.var(data)
# Out:
# 268.00350488888887

# %%
np.std(data)
# Out:
# 16.370812590976932

# %%
mpl.plot(data)

# %%
x=mpl.boxplot(data)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1528\2391820613.py in <module>
#       1 x=mpl.boxplot(data)
# ----> 2 x.outlier()
#
# AttributeError: 'dict' object has no attribute 'outlier'

# %%
np.std([-2000,-1000,0,1000,2000,3000])
# Out:
# 1707.825127659933
